# %%
import numpy as np

# %%
np.array([-2, 100, 41])

#datatype (type of the elements):int 
#the length, here the length is 3
# Out:
# array([ -2, 100,  41])

# %%
x= np.array([-2, False, 41])  
#datatype (type of the elements):int 
#the length, here the length is 3

# %%
x
# Out:
# array([-2,  0, 41])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
type(x[0]) 
#hierachy or numerical  type in python:
# bool,
# Out:
# numpy.int64

# %%
#for making evenly spaced array,
#start, stop, step, N
#interval with arange: half-open: [start, stop]
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.arange(-3,5)
# Out:
# array([-3, -2, -1,  0,  1,  2,  3,  4])

# %%
#also for evenly spaced arrays
np.linspace?
# when we specify the interval : CLOSED interval (by default): [start, stop]
# step=(stop-start)/(num-1) because the end point is included

# %%
A = np.linspace (-5,5)

# %%
A
# Out:
# array([-5.        , -4.79591837, -4.59183673, -4.3877551 , -4.18367347,
#        -3.97959184, -3.7755102 , -3.57142857, -3.36734694, -3.16326531,
#        -2.95918367, -2.75510204, -2.55102041, -2.34693878, -2.14285714,
#        -1.93877551, -1.73469388, -1.53061224, -1.32653061, -1.12244898,
#        -0.91836735, -0.71428571, -0.51020408, -0.30612245, -0.10204082,
#         0.10204082,  0.30612245,  0.51020408,  0.71428571,  0.91836735,
#         1.12244898,  1.32653061,  1.53061224,  1.73469388,  1.93877551,
#         2.14285714,  2.34693878,  2.55102041,  2.75510204,  2.95918367,
#         3.16326531,  3.36734694,  3.57142857,  3.7755102 ,  3.97959184,
#         4.18367347,  4.3877551 ,  4.59183673,  4.79591837,  5.        ])

# %%
A[0]
# Out:
# -5.0

# %%
len(A)
# Out:
# 50

# %%
type(A)
# Out:
# numpy.ndarray

# %%
type(A[0])
# Out:
# numpy.float64

# %%
#the step size: is the diff btn any two neigbors

A[21]-A[20]
# Out:
# 0.204081632653061

# %%
np.linspace (-5, 5, num=51)
# Out:
# array([-5. , -4.8, -4.6, -4.4, -4.2, -4. , -3.8, -3.6, -3.4, -3.2, -3. ,
#        -2.8, -2.6, -2.4, -2.2, -2. , -1.8, -1.6, -1.4, -1.2, -1. , -0.8,
#        -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,
#         1.6,  1.8,  2. ,  2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,
#         3.8,  4. ,  4.2,  4.4,  4.6,  4.8,  5. ])

# %%
B =np.linspace (-5, 5, num=51)

# %%
B[2]-B[1]
# Out:
# 0.20000000000000018

# %%
-4.8 - (-5.0)
# Out:
# 0.20000000000000018

# %%
H=np.linspace (-5, 5, num=21)

# %%
H[2]-H[1]
# Out:
# 0.5

# %%
np.arange(-10,10, 0.2)
# Out:
# array([-1.00000000e+01, -9.80000000e+00, -9.60000000e+00, -9.40000000e+00,
#        -9.20000000e+00, -9.00000000e+00, -8.80000000e+00, -8.60000000e+00,
#        -8.40000000e+00, -8.20000000e+00, -8.00000000e+00, -7.80000000e+00,
#        -7.60000000e+00, -7.40000000e+00, -7.20000000e+00, -7.00000000e+00,
#        -6.80000000e+00, -6.60000000e+00, -6.40000000e+00, -6.20000000e+00,
#        -6.00000000e+00, -5.80000000e+00, -5.60000000e+00, -5.40000000e+00,
#        -5.20000000e+00, -5.00000000e+00, -4.80000000e+00, -4.60000000e+00,
#        -4.40000000e+00, -4.20000000e+00, -4.00000000e+00, -3.80000000e+00,
#        -3.60000000e+00, -3.40000000e+00, -3.20000000e+00, -3.00000000e+00,
#        -2.80000000e+00, -2.60000000e+00, -2.40000000e+00, -2.20000000e+00,
#        -2.00000000e+00, -1.80000000e+00, -1.60000000e+00, -1.40000000e+00,
#        -1.20000000e+00, -1.00000000e+00, -8.00000000e-01, -6.00000000e-01,
# ...

# %%
#PLOTTING

# %%
import matplotlib.pyplot as plt

# %%
x=np.linspace (-2, 2, num=5)

# %%
print(x)
# Out:
# [-2. -1.  0.  1.  2.]

# %%
y = np.array([4, 1, 0, 1, 4])
print(y)
# Out:
# [4 1 0 1 4]

# %%
len(x)==len(y)
# Out:
# True

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'bo')
plt.show()

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(x,y,'r+')
plt.show()

# %%
plt.plot(x,y, color='green')
plt.show()

# %%
plt.plot(x,y, color='green', ls='--')
plt.show()

# %%
plt.plot(x,y, color='green',ls='--',lw=5)
plt.show()

# %%
plt.plot(x,y, color='green',ls='--',lw=5, marker='v',markerfacecolor='magenta')
plt.show()

# %%
plt.plot(x,y, color='deepskyblue',ls='--',lw=5, marker='v',markerfacecolor='magenta')
plt.show()

# %%
#Labling the plots

# %%
plt.plot(x,y, color='green',ls='--',lw=5, marker='v',markerfacecolor='magenta')
plt.xlabel('time(yrs)')
plt.ylabel('happiness $\omega$')
plt.title('LIFE')
plt.legend('yellow')
plt.show()

# %%
plt.text?

#this one the options of words we can use as KWARG

# %%
plt.plot(x,y, color='green',ls='--',lw=5, marker='v',markerfacecolor='magenta')
plt.xlabel('time(yrs)')
plt.ylabel('happiness $\omega$')
plt.title('LIFE', fontsize=20)
plt.legend('yellow')
plt.show()

# %%
plt.plot(B,H, color='green',ls='--',lw=5, marker='v',markerfacecolor='magenta')
plt.xlabel('time(yrs)')
plt.ylabel('happiness $\omega$')
plt.title('LIFE', fontsize=20)
plt.legend('yellow')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-245e0e3532e6> in <module>()
# ----> 1 plt.plot(B,H, color='green',ls='--',lw=5, marker='v',markerfacecolor='magenta')
#       2 plt.xlabel('time(yrs)')
#       3 plt.ylabel('happiness $\omega$')
#       4 plt.title('LIFE', fontsize=20)
#       5 plt.legend('yellow')
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1810                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1811                         RuntimeWarning, stacklevel=2)
# ...
